# %%
import sys
sys.path.append("..")

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_squared_log_error
from house_prices.preprocess import preprocess_data


def train_model(data: pd.DataFrame) -> LinearRegression:
    dp = preprocess_data(data)
    y_train = data["SalePrice"]
    X_train, X_test, y_train, y_test = train_test_split(
        dp, y_train, test_size=0.2, random_state=42)
    model = LinearRegression()
    model.fit(X_train, y_train)
    return model, X_test, y_test


def ev_model(model: LinearRegression, X_test: np.ndarray, y_test: np.ndarray):
    y_pred = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rmsle = np.sqrt(mean_squared_log_error(np.log(y_test), np.log(y_pred)))
    return rmse, rmsle


def build_model(data: pd.DataFrame) -> dict[str, str]:
    model, X_test, y_test = train_model(data)
    rmse, rmsle = ev_model(model, X_test, y_test)
    return {'rmse': str(rmse), 'rmsle': str(rmsle)}

# %%
 pip install dist/house_prices-0.1.tar.gz
# Out:
# Processing ./dist/house_prices-0.1.tar.gz
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /Users/admin-20218/miniconda3/lib/python3.10/site-packages (from house-prices==0.1) (1.5.3)
# Requirement already satisfied: numpy in /Users/admin-20218/miniconda3/lib/python3.10/site-packages (from house-prices==0.1) (1.23.5)
# Requirement already satisfied: scikit-learn in /Users/admin-20218/miniconda3/lib/python3.10/site-packages (from house-prices==0.1) (1.2.2)
# Requirement already satisfied: joblib in /Users/admin-20218/miniconda3/lib/python3.10/site-packages (from house-prices==0.1) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/admin-20218/miniconda3/lib/python3.10/site-packages (from pandas->house-prices==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/admin-20218/miniconda3/lib/python3.10/site-packages (from pandas->house-prices==0.1) (2022.7.1)
# Requirement already satisfied: scipy>=1.3.2 in /Users/admin-20218/miniconda3/lib/python3.10/site-packages (from scikit-learn->house-prices==0.1) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/admin-20218/miniconda3/lib/python3.10/site-packages (from scikit-learn->house-prices==0.1) (3.1.0)
# Requirement already satisfied: six>=1.5 in /Users/admin-20218/miniconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->house-prices==0.1) (1.16.0)
# Building wheels for collected packages: house-prices
#   Building wheel for house-prices (setup.py) ... done
#   Created wheel for house-prices: filename=house_prices-0.1-py3-none-any.whl size=1003 sha256=0c4b41c94d6b0034f942fab143e5e6896f0e25be9c3f420e6f1fc2837cb12f43
#   Stored in directory: /Users/admin-20218/Library/Caches/pip/wheels/da/dd/92/c38577e2490e0fa091e7c38b542b38b65fc44402ac2ff8023c
# Successfully built house-prices
# Installing collected packages: house-prices
# Successfully installed house-prices-0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- ---------
# absl-py                      1.4.0
# anyio                        3.6.2
# appnope                      0.1.3
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.2.3
# asttokens                    2.2.1
# astunparse                   1.6.3
# attrs                        22.2.0
# backcall                     0.2.0
# beautifulsoup4               4.11.2
# bleach                       6.0.0
# brotlipy                     0.7.0
# cachetools                   5.3.0
# certifi                      2022.12.7
# cffi                         1.15.1
# charset-normalizer           2.0.4
# click                        8.1.3
# comm                         0.1.2
# conda                        22.11.1
# conda-content-trust          0.1.3
# conda-package-handling       1.9.0
# contourpy                    1.0.7
# cryptography                 38.0.1
# cycler                       0.11.0
# debugpy                      1.6.6
# decorator                    5.1.1
# defusedxml                   0.7.1
# dnspython                    2.3.0
# executing                    1.2.0
# fastapi                      0.95.0
# fastjsonschema               2.16.3
# flake8                       6.0.0
# flatbuffers                  23.3.3
# fonttools                    4.38.0
# fqdn                         1.5.1
# gast                         0.4.0
# google-auth                  2.17.3
# google-auth-oauthlib         1.0.0
# google-pasta                 0.2.0
# grpcio                       1.54.0
# h11                          0.14.0
# h5py                         3.8.0
# house-prices                 0.1
# httptools                    0.5.0
# idna                         3.4
# ipykernel                    6.21.3
# ipython                      8.11.0
# ipython-genutils             0.2.0
# ipywidgets                   8.0.4
# isoduration                  20.11.0
# jax                          0.4.8
# jedi                         0.18.2
# Jinja2                       3.1.2
# joblib                       1.2.0
# jsonpointer                  2.3
# jsonschema                   4.17.3
# jupyter                      1.0.0
# jupyter_client               8.0.3
# jupyter-console              6.6.3
# jupyter_core                 5.2.0
# jupyter-events               0.6.3
# jupyter_server               2.4.0
# jupyter_server_terminals     0.4.4
# jupyterlab-pygments          0.2.2
# jupyterlab-widgets           3.0.5
# keras                        2.12.0
# kiwisolver                   1.4.4
# libclang                     16.0.0
# lxml                         4.9.2
# Markdown                     3.4.3
# MarkupSafe                   2.1.2
# matplotlib                   3.6.3
# matplotlib-inline            0.1.6
# mccabe                       0.7.0
# mistune                      2.0.5
# ml-dtypes                    0.1.0
# nbclassic                    0.5.3
# nbclient                     0.7.2
# nbconvert                    7.2.9
# nbformat                     5.7.3
# nest-asyncio                 1.5.6
# notebook                     6.5.3
# notebook_shim                0.2.2
# numpy                        1.23.5
# oauthlib                     3.2.2
# opt-einsum                   3.3.0
# packaging                    23.0
# pandas                       1.5.3
# pandocfilters                1.5.0
# parso                        0.8.3
# pexpect                      4.8.0
# pickleshare                  0.7.5
# Pillow                       9.4.0
# pip                          22.3.1
# platformdirs                 3.1.0
# pluggy                       1.0.0
# prometheus-client            0.16.0
# prompt-toolkit               3.0.38
# protobuf                     4.22.3
# psutil                       5.9.4
# psycopg2-binary              2.9.6
# ptyprocess                   0.7.0
# pure-eval                    0.2.2
# pyasn1                       0.5.0
# pyasn1-modules               0.3.0
# pycodestyle                  2.10.0
# pycosat                      0.6.4
# pycparser                    2.21
# pydantic                     1.10.7
# pyflakes                     3.0.1
# Pygments                     2.14.0
# pymongo                      4.3.3
# pyOpenSSL                    22.0.0
# pyparsing                    3.0.9
# pyrsistent                   0.19.3
# PySocks                      1.7.1
# python-dateutil              2.8.2
# python-dotenv                1.0.0
# python-json-logger           2.0.7
# pytube                       12.1.2
# pytz                         2022.7.1
# PyYAML                       6.0
# pyzmq                        25.0.0
# qtconsole                    5.4.0
# QtPy                         2.3.0
# requests                     2.28.1
# requests-oauthlib            1.3.1
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rsa                          4.9
# ruamel.yaml                  0.17.21
# ruamel.yaml.clib             0.2.6
# scikit-learn                 1.2.2
# scipy                        1.10.1
# seaborn                      0.12.2
# Send2Trash                   1.8.0
# setuptools                   65.5.0
# six                          1.16.0
# sniffio                      1.3.0
# soupsieve                    2.4
# stack-data                   0.6.2
# starlette                    0.26.1
# tensorboard                  2.12.2
# tensorboard-data-server      0.7.0
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.12.0
# tensorflow-estimator         2.12.0
# tensorflow-io-gcs-filesystem 0.32.0
# termcolor                    2.3.0
# terminado                    0.17.1
# threadpoolctl                3.1.0
# tinycss2                     1.2.1
# toolz                        0.12.0
# tornado                      6.2
# tqdm                         4.64.1
# traitlets                    5.9.0
# typing_extensions            4.5.0
# uri-template                 1.2.0
# urllib3                      1.26.13
# uvicorn                      0.21.1
# uvloop                       0.17.0
# watchfiles                   0.19.0
# wcwidth                      0.2.6
# webcolors                    1.12
# webencodings                 0.5.1
# websocket-client             1.5.1
# websockets                   11.0.1
# Werkzeug                     2.3.3
# wheel                        0.37.1
# widgetsnbextension           4.0.5
# wrapt                        1.14.1
# Note: you may need to restart the kernel to use updated packages.
